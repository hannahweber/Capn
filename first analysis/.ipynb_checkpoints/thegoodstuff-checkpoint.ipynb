# %%
#l = [i for i in range(len(ij)) if ij.loc[i]['Notes'].find("poison")!=-1]
#ij.loc[l]

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
ls
# Out:
# 2012-18_officialBoxScore.csv*  2017-18_standings.csv*
# 2012-18_playerBoxScore.csv*    2017-18_teamBoxScore.csv*
# 2012-18_standings.csv*         injuries.csv*
# 2012-18_teamBoxScore.csv*      metadata_officialBoxScore.pdf*
# 2016-17_officialBoxScore.csv*  metadata_playerBoxScore.pdf*
# 2016-17_playerBoxScore.csv*    metadata_standing.pdf*
# 2016-17_standings.csv*         metadata_teamBoxScore.pdf*
# 2016-17_teamBoxScore.csv*      teamBoxScore.csv*
# 2017-18_officialBoxScore.csv*  thegoodstuff.ipynb
# 2017-18_playerBoxScore.csv*

# %%
players = pd.read_csv("2012-18_playerBoxScore.csv")
players['gmDate']= players['gmDate'].apply(lambda x:pd.to_datetime(x))
players.head(2)
# Out:
#       gmDate gmTime  seasTyp playLNm playFNm teamAbbr teamConf    teamDiv  \
# 0 2012-10-30  19:00  Regular   Price    A.J.      WAS     East  Southeast
# 1 2012-10-30  19:00  Regular   Ariza  Trevor      WAS     East  Southeast
#
#   teamLoc teamRslt  teamDayOff   offLNm1 offFNm1 offLNm2  offFNm2  offLNm3  \
# 0    Away     Loss           0  Brothers    Tony   Smith  Michael  Workman
# 1    Away     Loss           0  Brothers    Tony   Smith  Michael  Workman
#
#     offFNm3    playDispNm playStat  playMin playPos  playHeight  playWeight  \
# 0  Haywoode    A.J. Price  Starter       29      PG          74         195
# 1  Haywoode  Trevor Ariza  Starter       25      SG          80         200
#
#     playBDate  playPTS  playAST  playTO  playSTL  playBLK  playPF  playFGA  \
# 0  1986-10-07        7        6       1        0        0       1       13
# 1  1985-06-30        9        4       0        3        2       0        8
#
#    playFGM  playFG%  play2PA  play2PM  play2P%  play3PA  play3PM  play3P%  \
# 0        2   0.1538        4        0     0.00        9        2   0.2222
# 1        3   0.3750        4        1     0.25        4        2   0.5000
#
#    playFTA  playFTM  playFT%  playORB  playDRB  playTRB opptAbbr opptConf  \
# 0        1        1      1.0        1        1        2      CLE     East
# 1        2        1      0.5        1        2        3      CLE     East
#
#    opptDiv opptLoc opptRslt  opptDayOff
# 0  Central    Home      Win           0
# 1  Central    Home      Win           0

# %%
ij = pd.read_csv("injuries.csv")
ij['Date'] = ij['Date'].apply(lambda x:pd.to_datetime(x))
ij = ij[ij['Date']>pd.to_datetime("2012-10-29")]
ij.head(2)
# Out:
#            Date     Team Acquired    Relinquised  \
# 2218 2012-10-30    Bulls      NaN   Derrick Rose
# 2219 2012-10-30  Celtics      NaN  Darko Milicic
#
#                                                   Notes
# 2218  recovering from surgery on left knee to repair...
# 2219                                  back spasms (DTD)

# %%
# If you look at the 'Notes' column above, there are lots of similar kinds
# of injuries that I wanted to group together. This manually combines a
# lot of them into more easily analyzable categories.
l = []
for i in ij['Notes']:
    if i.find('ankle')!=-1:
        l.append('ankle')
    elif i.find("torn")!=-1:
        l.append(i)
    elif i.find("knee")!=-1:
        l.append("knee")
    elif i.find("head")!=-1:
        l.append("head")
    elif i.find("knee")!=-1:
        l.append("knee")
    elif i.find("calf")!=-1:
        l.append("calf")
    elif i.find("elbow")!=-1:
        l.append("elbow")
    elif i.find("wrist")!=-1:
        l.append("wrist")
    elif i.find("hand")!=-1:
        l.append("hand")
    elif i.find("foot")!=-1:
        l.append("foot")
    elif i.find("back")!=-1:
        l.append("back")
    elif i.find("concussion")!=-1:
        l.append("concussion")
    elif i.find("hamstring")!=-1:
        l.append("hamstring")
    elif i.find("illness")!=-1:
        l.append("illness")
    elif i.find("rest")!=-1:
        l.append("rest")
    
    elif i==i:
        l.append(i)
    else:
        l.append("nan")
ij['Notes'] = l

# %%
biggest = []
nmf = []
for typeof in ij['Notes'].value_counts()[1:13].index: # For each type of injury
    df_injury = ij[ij['Notes']==typeof] #               Then filter the df
    bigger = []#                                        Create list which we will build up
    for player in df_injury['Relinquised'].unique():  # For each player in injuries df
        player_injuries = [t for t in df_injury[df_injury['Relinquised']==player]['Date']] # Grab all the dates of said players injuries
        if len(player_injuries)==0:
            print("Player does not have any recorded injuries:",player)
            pass
        #try:
        ln = player.split()[1] # Players df holds names in two different categories
        fn = player.split()[0]
        for i in range(len(player_injuries)): # For each injury that player had
            date = player_injuries[i]    #      Find date of injury
            try:                         #      We need to set a date of previous injury, if there is one
                dateM1 = player_injuries[i-1] # If we can find it, we set it
            except:
                dateM1 = pd.to_datetime("1990-01-01")# If we can't, we set previous date until way in the past
            try:
                dateP1 = player_injuries[i+1] # Same for next injury
            except:
                dateP1 = pd.to_datetime("2090-01-01")

            b = players[players['playLNm']==ln] # Find that players games
            b = b[b['playFNm']==fn].reset_index()

            if len(b>0):
                #print(len(b),"matches found for player name",fn,ln)
                pass
            else:
                nmf.append(fn+" "+ln)
                #print("No matches found for player name",fn,ln)

            if len(b[b['gmDate']==date])>0: # This is testing if the injury happened during a game
                g = 1
                game_injury_index = b[b['gmDate']==date].index[0]
                #print("During game")

            else:
                #Injury did not happen during a game if it got here, so pass (aka discard)
                pass

            #print("here")
            for daterange in range(game_injury_index-7,game_injury_index):
                try:
                    row = b.loc[daterange] # Grab a specific row
                    if row.gmDate >dateM1: # Making sure that the game wasn't prior to a different injury
                        pre = [daterange-game_injury_index,row.gmDate,row.playPTS,row.playMin,row.playAST] # Build a list of useful info
                        bigger.append(pre)# Add list to bigger list
                        #print("added")
                except:# If we get to this point, it means it couldnt find a previous game of that number
                    #print("row")
                    pass # E.g. It couldnt find the 7th previous game to the injury

                try:
                    row = b.loc[daterange+7+g]
                    if row.gmDate<dateP1: # Same as above, but with games AFTER injury
                        post = [daterange-game_injury_index+8,row.gmDate,row.playPTS,row.playMin,row.playAST]
                        bigger.append(post)
                except: # Same as above except statement
                    pass
        #except:
            #print(player) # This means something weird happened, so print the players name
    biggest.append({typeof:bigger})
nmf = set(nmf)
print(nmf)
# Out:
# {'James Michael', 'Goran Dragic', 'Zaur Pachulia', 'Trey Burke', 'Victor Oladipo', 'Robbie Hummel', 'Frank Jackson', 'Kris Joseph', 'T.J. Warren', 'Shane Larkin', 'T.J. Leaf', 'Luke Harangody', 'Pat Connaughton', 'Ben Simmons', 'Josh Smith', 'Amare Stoudemire', 'Jonas Valanciunas', 'Josh McRoberts', 'Alex Len', 'Will Bynum', 'Jose Juan', 'Timothe Luwawu', 'Raulzinho Neto', 'Fab Melo', 'Jerami Grant', 'Nemanja Nedovic', 'Will Barton', 'C.J. Miles', 'Metta World', 'Greg Stiemsma', 'Mike Muscala', 'Cristiano Felicio', 'Kostas Papanikolaou', 'Nikola Vucevic', 'Stephen Curry', 'Juancho Hernangomez', 'Reggie Bullock', 'Bojan Bogdanovic', 'J.R. Smith', '(William) Tony', 'Doug McDermott', 'Dennis Schroder', 'Frank Kaminsky', 'D.J. Augustine', 'Alex Abrines', 'C.J. Wilcox', 'Chuck Hayes', 'Tomas Satoransky', 'Ognjen Kuzmic', 'Zach LaVine', 'Joe Ingles', 'Nik Stauskas', 'Markel Brown', 'Nikola Mirotic', 'Kosta Koufos', 'J.J. Redick', 'Mitch McGary', 'Joe Young', 'Ike Anigbogu', 'C.J. Watson', 'P.J. Tucker', 'C.J. McCollum', 'Festus Ezeli', 'Chris Kaman', 'Ronnie Price', 'Vince Carter', 'T.J. McConnell', 'Harry Giles', 'Nene /', 'Tim Hardaway', 'Henry Walker', 'Ed Davis', 'Andre Roberson', 'Kristaps Porzingis', 'Emanuel Ginobili', 'Donatas Motiejunas', "DeAndre' Bembry", 'Hollis Thompson', 'Damjan Rudez', 'Ben Gordon', 'Brice Johnson', 'Luc Richard', 'Nikola Jokic', 'Chris McCullough', 'Mirza Teletovic', 'Skal Labissiere', 'P.J. Hairston'}

# %%
df_l = []
for i in biggest:
    for key,item in i.items():
        df = pd.DataFrame(item)
        #print(df)
        df.columns = ['day','date','pts','min','ast']
        df_l.append([key,df])
for i in df_l:
    i[1]=i[1].groupby('day').agg({'pts':np.mean}).reset_index()
    a=sb.factorplot(x='day',y='pts',data=i[1],sharey=False,color='black',aspect=1.25)
    a.axes[0,0].set_title(i[0]+" injury")
    plt.ylim(0,20)
    a.axes[0,0].axvline(6.5,lw=1,c='r',ls='--',zorder=100)
    #plt.plot([0, 4], [1.5, 0], linewidth=2)
    plt.xlabel("Games Before/After Injury")
    plt.ylabel("Points On Average")
plt.show()

# %%
df_l = []
for i in biggest:
    for key,item in i.items():
        df = pd.DataFrame(item)
        df.columns = ['day','date','pts','min','ast']
        df_l.append([key,df])
for i in df_l:
    i[1]=i[1].groupby('day').agg({'pts':np.mean,'min':np.mean}).reset_index()
    i[1]['pts/min']=i[1]['pts']/i[1]['min']
    a=sb.factorplot(x='day',y='pts/min',data=i[1],sharey=False,color='black',aspect=1.25)
    a.axes[0,0].set_title(i[0]+" injury")
    plt.ylim(0,1)
    a.axes[0,0].axvline(6.5,lw=1,c='r',ls='--',zorder=100)
    #plt.plot([0, 4], [1.5, 0], linewidth=2)
    plt.xlabel("Games Before/After Injury")
    plt.ylabel("Points On Average Per Minute")
plt.show()

# %%
# Out:
# '/Users/darude/Desktop/Python/capn/first analysis'

# %%
df_l = []
for i in biggest:
    for key,item in i.items():
        df = pd.DataFrame(item)
        df.columns = ['day','date','pts','min','ast']
        df_l.append([key,df])

# %%
df=0
for i in df_l:
    i[1]=i[1].groupby('day').agg({'pts':np.mean,'min':np.mean}).reset_index()
    i[1]['pts/min']=i[1]['pts']/i[1]['min']
    i[1]['inj']=[i[0] for j in range(len(i[1]))]
    try:
        df = df.append(i[1])
    except:
        #print(i[1])
        df=i[1]

# %%
df = df.set_index('day')

# %%
f,axs = plt.subplots(4,3,figsize=(15,15))
for i in range(4):
    for e in range(3):
        t = df['inj'].unique()[i*3+e]
        df[df['inj']==t]['pts'].plot(ax=axs[i][e],c='b')
        axs[i][e].set_title(t)
        axs[i][e].axis(ymin=0,ymax=20,xlabel="Games Before/After Injury")
        axs[i][e].axvline(0,lw=1,c='k',ls='--',zorder=100)
        axs[i][e].set_xlabel(xlabel="Games Before/After Injury")
        axs[i][e].set_ylabel(ylabel="Points Per Game")
#axs.set_axis_labels("Games Before/After Injury","Points per Game")
plt.subplots_adjust(bottom=9,top=10)

# %%
f,axs = plt.subplots(4,3,figsize=(15,15))
for i in range(4):
    for e in range(3):
        t = df['inj'].unique()[i*3+e]
        df[df['inj']==t]['pts/min'].plot(ax=axs[i][e],c='b')
        axs[i][e].set_title(t)
        axs[i][e].axis(ymin=0,ymax=1,xlabel="Games Before/After Injury")
        axs[i][e].axvline(0,lw=1,c='k',ls='--',zorder=100)
        axs[i][e].set_xlabel(xlabel="Games Before/After Injury")
        axs[i][e].set_ylabel(ylabel="Points Per Minute Played Per Game")
#axs.set_axis_labels("Games Before/After Injury","Points per Game")
plt.subplots_adjust(bottom=9,top=10)
