# %% [markdown]
# ## Primary way of scraping https://stats.nba.com/players/boxscores/?Season=2011-12&SeasonType=Regular%20Season for 2011-2012 data

# %%
import time
import requests as req
import re
import pprint
from bs4 import BeautifulSoup, Comment
import pandas as pd
import time

a = req.get("https://stats.nba.com/players/boxscores/?Season=2011-12&SeasonType=Regular%20Season")
soup = BeautifulSoup(a.content, 'html.parser')
#soup




# This way is fucked without doing mad work
# Out:
# <!DOCTYPE html>
#
# <html lang="en" ng-app="stats" ng-strict-di="" stats-build-date="2020-03-13 01:22 PM" stats-version="4.26.2" xmlns:ng="http://angularjs.org">
# <head>
# <meta charset="utf-8"/>
# ...

# %% [markdown]
# ## Second way (not ideal): using a mock web browser
# Cookies please don't fuck me over
#
# ### Note: To use this yourself, you will need to install the 'selenium' package. To do this, the easiest way is to go into terminal:
# 1.) Open up a NEW terminal window, I'd recommend hitting command + n
#
# 2.) typing in 'pip install selenium' and hitting enter
#
# 3.) Thats it, then run the code below

# %%
# Import libraries for getting data from the web and parsing XML documents
import numpy as np
import re
import string
import requests
from bs4 import BeautifulSoup, Comment
from bs4 import NavigableString, Tag
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup

browser = webdriver.Chrome('/Users/darude/chromedriver')
base_url = u'https://twitter.com/search?q='
query = u'memes&src=typd'

url = "https://stats.nba.com/players/boxscores/?Season=2011-12&SeasonType=Regular%20Season"
listOfInfo = []
counter = 0
pre=""

browser.get(url)
time.sleep(5)

while True:
    #if counter==416:
    #    break
    body = browser.find_element_by_tag_name('tbody')
    if body==pre:
        break
    else:
        pre = body
    tags = browser.find_element_by_tag_name('tr')

    time.sleep(1)
    
    i=0
    a = body.text.split('\n')
    while True:
        try:
            listOfInfo.append([a[i],a[i+1]])
            #d[a[i]]=a[i+1]
            i+=2
        except:
            break

    #python_button = browser.find_elements_by_xpath("//a[@href alt='Next Page' and @ng-click='nav(1)']")[0]
    try:
        python_button = browser.find_elements_by_xpath("/html/body/main/div[2]/div/div[2]/div/div/nba-stat-table/div[1]/div/div/a[2]")[0]
        python_button.click()
    except:
        print(counter)
        
    counter+=1

#a = browser.find_element_by_tag_name("a.stats-table-pagination__next")

    
#tweets = browser.find_elements_by_class_name('data-ng-repeat')

#for tweet in tweets:
#    print(tweet.text)
# Out:
# 0
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# ...

# %%
len(listOfInfo)
# Out:
# 21494

# %%
i=0
d=[]
a = body.text.split('\n')
while True:
    try:
        d.append([a[i],a[i+1]])
        #d[a[i]]=a[i+1]
        i+=2
    except:
        break
d
# Out:
# [['James Singleton',
#   'WAS WAS vs. MIA 04/26/2012 W 22 4 2 4 50.0 0 0 - 0 0 - 1 7 8 3 0 0 1 3 18'],
#  ['Kevin Seraphin',
#   'WAS WAS vs. MIA 04/26/2012 W 25 15 6 10 60.0 0 0 - 3 4 75.0 1 2 3 0 0 0 1 1 16'],
#  ['Norris Cole',
#   'MIA MIA @ WAS 04/26/2012 L 31 14 6 10 60.0 0 0 - 2 2 100 0 0 0 2 0 0 4 1 -23'],
#  ['Udonis Haslem',
#   'MIA MIA @ WAS 04/26/2012 L 19 6 2 5 40.0 0 0 - 2 2 100 2 2 4 1 1 1 0 0 -11'],
#  ['Nene',
#   'WAS WAS vs. MIA 04/26/2012 W 19 15 6 7 85.7 0 0 - 3 5 60.0 1 6 7 3 0 2 2 2 13'],
#  ['Ronny Turiaf',
#   'MIA MIA @ WAS 04/26/2012 L 18 5 1 2 50.0 0 0 - 3 4 75.0 1 4 5 1 3 1 1 3 -10'],
#  ['Maurice Evans',
#   'WAS WAS vs. MIA 04/26/2012 W 23 18 7 13 53.8 2 3 66.7 2 3 66.7 0 0 0 0 1 0 0 2 19'],
#  ['John Wall',
#   'WAS WAS vs. MIA 04/26/2012 W 25 7 3 8 37.5 0 0 - 1 2 50.0 0 2 2 12 2 0 2 2 19'],
#  ['James Jones',
#   'MIA MIA @ WAS 04/26/2012 L 29 8 3 9 33.3 1 5 20.0 1 2 50.0 0 2 2 0 0 0 1 2 -23'],
#  ['Juwan Howard',
# ...
